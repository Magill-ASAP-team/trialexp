# %%
import pandas as pd
import os
from pathlib import Path

# %%
path = Path('Julien/Data/head-fixed/videos/12-15-22_14-54-57.000_JC317L_Rig_3_SideDLC_resnet50_side_2_hands_newobjAug26shuffle1_700000.h5')
path = os.path.join('/home/MRC.OX.AC.UK/ndcn1330/ettin', path)
print(path)
# Out:
# /home/MRC.OX.AC.UK/ndcn1330/ettin/Julien/Data/head-fixed/videos/12-15-22_14-54-57.000_JC317L_Rig_3_SideDLC_resnet50_side_2_hands_newobjAug26shuffle1_700000.h5

# %%
pd.read_hdf(path)
# Out:
# scorer    DLC_resnet50_side_2_hands_newobjAug26shuffle1_700000              \
# bodyparts                                             shoulder
# coords                                                       x           y
# 0                                                1138.793335    390.617371
# 1                                                1138.787109    390.614868
# 2                                                1138.758911    390.738159
# 3                                                1138.765747    390.731659
# 4                                                1138.466675    392.249176
# ...                                                      ...           ...
# 9642                                             1077.415894    432.374939
# 9643                                             1076.559082    432.548492
# 9644                                             1074.779907    433.157440
# 9645                                             1072.374146    447.163239
# ...

# %%
model = 'Z:\Julien\Models\side_2_hands_newobj-julien-2022-08-26\evaluation-results\iteration-0\side_2_hands_newobjAug26-trainset95shuffle1'
